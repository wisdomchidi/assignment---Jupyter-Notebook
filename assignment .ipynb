# %%
import pandas as pd

# %%
cvsdata = pd.read_csv('https://github.com/HamoyeHQ/HDSC-Introduction-to-Python-for-machine-learning/files/7768140/FoodBalanceSheets_E_Africa_NOFLAG.csv')
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2820/1277450056.py in <module>
# ----> 1 cvsdata = pd.read_csv('https://github.com/HamoyeHQ/HDSC-Introduction-to-Python-for-machine-learning/files/7768140/FoodBalanceSheets_E_Africa_NOFLAG.csv')
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
df = pd.read_csv('https://github.com/HamoyeHQ/HDSC-Introduction-to-Python-for-machine-learning/files/7768140/FoodBalanceSheets_E_Africa_NOFLAG.csv?raw=true.csv',encoding='Latin-1')

# %%
print(df)
# Out:
#        Area Code      Area  Item Code           Item  Element Code  \
# 0              4   Algeria       2501     Population           511
# 1              4   Algeria       2501     Population          5301
# 2              4   Algeria       2901    Grand Total           664
# 3              4   Algeria       2901    Grand Total           674
# 4              4   Algeria       2901    Grand Total           684
# ...          ...       ...        ...            ...           ...
# 60938        181  Zimbabwe       2899  Miscellaneous          5142
# 60939        181  Zimbabwe       2899  Miscellaneous           645
# 60940        181  Zimbabwe       2899  Miscellaneous           664
# 60941        181  Zimbabwe       2899  Miscellaneous           674
# 60942        181  Zimbabwe       2899  Miscellaneous           684
#
#                                       Element             Unit     Y2014  \
# 0               Total Population - Both sexes     1000 persons  38924.00
# ...

# %%
df.head(20)
# Out:
#     Area Code     Area  Item Code                      Item  Element Code  \
# 0           4  Algeria       2501                Population           511
# 1           4  Algeria       2501                Population          5301
# 2           4  Algeria       2901               Grand Total           664
# 3           4  Algeria       2901               Grand Total           674
# 4           4  Algeria       2901               Grand Total           684
# 5           4  Algeria       2903          Vegetal Products           664
# 6           4  Algeria       2903          Vegetal Products           674
# 7           4  Algeria       2903          Vegetal Products           684
# 8           4  Algeria       2941           Animal Products           664
# 9           4  Algeria       2941           Animal Products           674
# 10          4  Algeria       2941           Animal Products           684
# 11          4  Algeria       2905  Cereals - Excluding Beer          5511
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of        Area Code      Area  Item Code           Item  Element Code  \
# 0              4   Algeria       2501     Population           511
# 1              4   Algeria       2501     Population          5301
# 2              4   Algeria       2901    Grand Total           664
# 3              4   Algeria       2901    Grand Total           674
# 4              4   Algeria       2901    Grand Total           684
# ...          ...       ...        ...            ...           ...
# 60938        181  Zimbabwe       2899  Miscellaneous          5142
# 60939        181  Zimbabwe       2899  Miscellaneous           645
# 60940        181  Zimbabwe       2899  Miscellaneous           664
# 60941        181  Zimbabwe       2899  Miscellaneous           674
# 60942        181  Zimbabwe       2899  Miscellaneous           684
#
#                                       Element             Unit     Y2014  \
# ...

# %%
df.tail(20)
# Out:
#        Area Code      Area  Item Code           Item  Element Code  \
# 60923        181  Zimbabwe       2680    Infant food          5611
# 60924        181  Zimbabwe       2680    Infant food          5072
# 60925        181  Zimbabwe       2680    Infant food          5911
# 60926        181  Zimbabwe       2680    Infant food          5301
# 60927        181  Zimbabwe       2680    Infant food          5170
# 60928        181  Zimbabwe       2680    Infant food          5142
# 60929        181  Zimbabwe       2680    Infant food           645
# 60930        181  Zimbabwe       2680    Infant food           664
# 60931        181  Zimbabwe       2680    Infant food           674
# 60932        181  Zimbabwe       2680    Infant food           684
# 60933        181  Zimbabwe       2899  Miscellaneous          5611
# 60934        181  Zimbabwe       2899  Miscellaneous          5072
# 60935        181  Zimbabwe       2899  Miscellaneous          5911
# ...

# %%
df.groupby('Y2014').sum()
# Out:
#            Area Code  Item Code  Element Code     Y2015     Y2016     Y2017  \
# Y2014
# -1796.0          159       2657          5072     -73.0     -12.0       0.0
# -1631.0          159       2924          5072       6.0     -77.0    -689.0
# -849.0           266       5444         10340   -1118.0   -1119.0   -1200.0
# -838.0           184       2907          5072    -827.0    -679.0    -538.0
# -685.0           143       2905          5072    3418.0   -3225.0     689.0
# ...              ...        ...           ...       ...       ...       ...
#  90425.0          59       2501           511   92443.0   94447.0   96443.0
#  98094.0         238       2501           511  100835.0  103603.0  106400.0
#  108756.0        159       2907          5301  110798.0  116483.0  112625.0
#  109593.0        159       2907          5511  111663.0  119330.0  117702.0
#  176405.0        159       2501           511  181137.0  185960.0  190873.0
#
#               Y2018
# Y2014
# ...

# %%
df.plot()
# Out:
# Matplotlib is building the font cache; this may take a moment.
# <AxesSubplot:>

# %%
df['Y2014'].plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df('Fat')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2820/1034476880.py in <module>
# ----> 1 df('Fat')
#
# TypeError: 'DataFrame' object is not callable
